# %%
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\YUSEF\Downloads\Compressed\Airbnb_Open_Data.csv\Airbnb_Open_Data.csv')
df
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\1092840129.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r'C:\Users\YUSEF\Downloads\Compressed\Airbnb_Open_Data.csv\Airbnb_Open_Data.csv')
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 3              Clinton Hill  40.68514 -73.95976  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
# 102598      Upper West Side  40.76807 -73.98342  United States  ...
#
#        service fee minimum nights number of reviews last review  \
# 0            $193            10.0               9.0  10/19/2021
# 1             $28            30.0              45.0   5/21/2022
# 2            $124             3.0               0.0         NaN
# 3             $74            30.0             270.0    7/5/2019
# 4             $41            10.0               9.0  11/19/2018
# ...            ...            ...               ...         ...
# 102594       $169             1.0               0.0         NaN
# 102595       $167             1.0               1.0    7/6/2015
# 102596       $198             3.0               0.0         NaN
# 102597       $109             2.0               5.0  10/11/2015
# 102598       $206             1.0               0.0         NaN
#
#         reviews per month review rate number calculated host listings count  \
# 0                    0.21                4.0                            6.0
# 1                    0.38                4.0                            2.0
# 2                     NaN                5.0                            1.0
# 3                    4.64                4.0                            1.0
# 4                    0.10                3.0                            1.0
# ...                   ...                ...                            ...
# 102594                NaN                3.0                            1.0
# 102595               0.02                2.0                            2.0
# 102596                NaN                5.0                            1.0
# 102597               0.10                3.0                            1.0
# 102598                NaN                3.0                            1.0
#
#         availability 365                                        house_rules  \
# 0                  286.0  Clean up and treat the home the way you'd like...
# 1                  228.0  Pet friendly but please confirm with me if the...
# 2                  352.0  I encourage you to use my kitchen, cooking and...
# 3                  322.0                                                NaN
# 4                  289.0  Please no smoking in the house, porch or on th...
# ...                  ...                                                ...
# 102594             227.0  No Smoking No Parties or Events of any kind Pl...
# 102595             395.0  House rules: Guests agree to the following ter...
# 102596             342.0                                                NaN
# 102597             386.0                                                NaN
# 102598              69.0                                                NaN
#
#        license
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 102594     NaN
# 102595     NaN
# 102596     NaN
# 102597     NaN
# 102598     NaN
#
# [102599 rows x 26 columns]

# %%
df.license.value_counts()
#! drop this shit
# Out:
# license
# 41662/AL    2
# Name: count, dtype: int64

# %%
df.drop(columns='license',inplace=True)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...    price  \
# 0                Kensington  40.64749 -73.97237  United States  ...    $966
# 1                   Midtown  40.75362 -73.98377  United States  ...    $142
# 2                    Harlem  40.80902 -73.94190  United States  ...    $620
# 3              Clinton Hill  40.68514 -73.95976  United States  ...    $368
# 4               East Harlem  40.79851 -73.94399  United States  ...    $204
# ...                     ...       ...       ...            ...  ...      ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...    $844
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...    $837
# 102596           Park Slope  40.67505 -73.98045  United States  ...    $988
# 102597     Long Island City  40.74989 -73.93777  United States  ...    $546
# 102598      Upper West Side  40.76807 -73.98342  United States  ...  $1,032
#
#        service fee minimum nights number of reviews  last review  \
# 0            $193            10.0               9.0   10/19/2021
# 1             $28            30.0              45.0    5/21/2022
# 2            $124             3.0               0.0          NaN
# 3             $74            30.0             270.0     7/5/2019
# 4             $41            10.0               9.0   11/19/2018
# ...            ...            ...               ...          ...
# 102594       $169             1.0               0.0          NaN
# 102595       $167             1.0               1.0     7/6/2015
# 102596       $198             3.0               0.0          NaN
# 102597       $109             2.0               5.0   10/11/2015
# 102598       $206             1.0               0.0          NaN
#
#        reviews per month review rate number  calculated host listings count  \
# 0                   0.21                4.0                             6.0
# 1                   0.38                4.0                             2.0
# 2                    NaN                5.0                             1.0
# 3                   4.64                4.0                             1.0
# 4                   0.10                3.0                             1.0
# ...                  ...                ...                             ...
# 102594               NaN                3.0                             1.0
# 102595              0.02                2.0                             2.0
# 102596               NaN                5.0                             1.0
# 102597              0.10                3.0                             1.0
# 102598               NaN                3.0                             1.0
#
#         availability 365                                        house_rules
# 0                  286.0  Clean up and treat the home the way you'd like...
# 1                  228.0  Pet friendly but please confirm with me if the...
# 2                  352.0  I encourage you to use my kitchen, cooking and...
# 3                  322.0                                                NaN
# 4                  289.0  Please no smoking in the house, porch or on th...
# ...                  ...                                                ...
# 102594             227.0  No Smoking No Parties or Events of any kind Pl...
# 102595             395.0  House rules: Guests agree to the following ter...
# 102596             342.0                                                NaN
# 102597             386.0                                                NaN
# 102598              69.0                                                NaN
#
# [102599 rows x 25 columns]

# %%
df.host_identity_verified.unique()
# Out:
# array(['unconfirmed', 'verified', nan], dtype=object)

# %%
df.host_identity_verified.isna().value_counts()
#! 289
# Out:
# host_identity_verified
# False    102310
# True        289
# Name: count, dtype: int64

# %%
df.host_identity_verified.isna()
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 102594    False
# 102595    False
# 102596    False
# 102597    False
# 102598    False
# Name: host_identity_verified, Length: 102599, dtype: bool

# %%
df.host_identity_verified
# Out:
# 0         unconfirmed
# 1            verified
# 2                 NaN
# 3         unconfirmed
# 4            verified
#              ...
# 102594       verified
# 102595    unconfirmed
# 102596    unconfirmed
# 102597    unconfirmed
# 102598    unconfirmed
# Name: host_identity_verified, Length: 102599, dtype: object

# %%
df.host_identity_verified.value_counts()
# Out:
# host_identity_verified
# unconfirmed    51200
# verified       51110
# Name: count, dtype: int64

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...    price  \
# 0                Kensington  40.64749 -73.97237  United States  ...    $966
# 1                   Midtown  40.75362 -73.98377  United States  ...    $142
# 2                    Harlem  40.80902 -73.94190  United States  ...    $620
# 3              Clinton Hill  40.68514 -73.95976  United States  ...    $368
# 4               East Harlem  40.79851 -73.94399  United States  ...    $204
# ...                     ...       ...       ...            ...  ...      ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...    $844
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...    $837
# 102596           Park Slope  40.67505 -73.98045  United States  ...    $988
# 102597     Long Island City  40.74989 -73.93777  United States  ...    $546
# 102598      Upper West Side  40.76807 -73.98342  United States  ...  $1,032
#
#        service fee minimum nights number of reviews  last review  \
# 0            $193            10.0               9.0   10/19/2021
# 1             $28            30.0              45.0    5/21/2022
# 2            $124             3.0               0.0          NaN
# 3             $74            30.0             270.0     7/5/2019
# 4             $41            10.0               9.0   11/19/2018
# ...            ...            ...               ...          ...
# 102594       $169             1.0               0.0          NaN
# 102595       $167             1.0               1.0     7/6/2015
# 102596       $198             3.0               0.0          NaN
# 102597       $109             2.0               5.0   10/11/2015
# 102598       $206             1.0               0.0          NaN
#
#        reviews per month review rate number  calculated host listings count  \
# 0                   0.21                4.0                             6.0
# 1                   0.38                4.0                             2.0
# 2                    NaN                5.0                             1.0
# 3                   4.64                4.0                             1.0
# 4                   0.10                3.0                             1.0
# ...                  ...                ...                             ...
# 102594               NaN                3.0                             1.0
# 102595              0.02                2.0                             2.0
# 102596               NaN                5.0                             1.0
# 102597              0.10                3.0                             1.0
# 102598               NaN                3.0                             1.0
#
#         availability 365                                        house_rules
# 0                  286.0  Clean up and treat the home the way you'd like...
# 1                  228.0  Pet friendly but please confirm with me if the...
# 2                  352.0  I encourage you to use my kitchen, cooking and...
# 3                  322.0                                                NaN
# 4                  289.0  Please no smoking in the house, porch or on th...
# ...                  ...                                                ...
# 102594             227.0  No Smoking No Parties or Events of any kind Pl...
# 102595             395.0  House rules: Guests agree to the following ter...
# 102596             342.0                                                NaN
# 102597             386.0                                                NaN
# 102598              69.0                                                NaN
#
# [102599 rows x 25 columns]

# %%
dfc = df.dropna(subset=['NAME','host_identity_verified','host name','neighbourhood group','neighbourhood','lat','long','country','country code','price','Construction year','room type','cancellation_policy','instant_bookable','service fee','availability 365','calculated host listings count','review rate number','reviews per month','number of reviews','minimum nights'])

# %%
dfc.dropna(subset='last review',inplace=True)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\2139616325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.dropna(subset='last review',inplace=True)

# %%
dfc
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# 7       1005202                                   BlissArtsSpace!
# ...         ...                                               ...
# 102588  6089124          Loft Space for Events, Meetings & Shoots
# 102591  6090781                Columbus Ave Apt 1 block from Park
# 102593  6091885               Welcoming, Clean, Cheap on St Marks
# 102595  6092990                     Best Location near Columbia U
# 102597  6094094                  Big Studio-One Stop from Midtown
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 4       92037596077               verified       Lyndon           Manhattan
# 5       45498551794               verified     Michelle           Manhattan
# 7       90821839709            unconfirmed         Emma            Brooklyn
# ...             ...                    ...          ...                 ...
# 102588  85557432222            unconfirmed        Kalin           Manhattan
# 102591  50908010324               verified     Lawrence           Manhattan
# 102593  33188605074               verified       Felipe           Manhattan
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102597  11160591270            unconfirmed  Christopher              Queens
#
#               neighbourhood       lat      long        country  ...    price  \
# 0                Kensington  40.64749 -73.97237  United States  ...    $966
# 1                   Midtown  40.75362 -73.98377  United States  ...    $142
# 4               East Harlem  40.79851 -73.94399  United States  ...    $204
# 5               Murray Hill  40.74767 -73.97500  United States  ...    $577
# 7        Bedford-Stuyvesant  40.68688 -73.95596  United States  ...  $1,060
# ...                     ...       ...       ...            ...  ...      ...
# 102588    Flatiron District  40.74068 -73.98999  United States  ...    $618
# 102591      Upper West Side  40.77408 -73.98181  United States  ...  $1,139
# 102593         East Village  40.72826 -73.98422  United States  ...  $1,099
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...    $837
# 102597     Long Island City  40.74989 -73.93777  United States  ...    $546
#
#        service fee minimum nights number of reviews  last review  \
# 0            $193            10.0               9.0   10/19/2021
# 1             $28            30.0              45.0    5/21/2022
# 4             $41            10.0               9.0   11/19/2018
# 5            $115             3.0              74.0    6/22/2019
# 7            $212            45.0              49.0    10/5/2017
# ...            ...            ...               ...          ...
# 102588       $124             1.0             177.0    6/29/2019
# 102591       $228             5.0              17.0     1/4/2019
# 102593       $220             1.0               8.0     9/6/2015
# 102595       $167             1.0               1.0     7/6/2015
# 102597       $109             2.0               5.0   10/11/2015
#
#        reviews per month review rate number  calculated host listings count  \
# 0                   0.21                4.0                             6.0
# 1                   0.38                4.0                             2.0
# 4                   0.10                3.0                             1.0
# 5                   0.59                3.0                             1.0
# 7                   0.40                5.0                             1.0
# ...                  ...                ...                             ...
# 102588              3.78                4.0                             1.0
# 102591              0.35                5.0                             1.0
# 102593              0.16                4.0                             2.0
# 102595              0.02                2.0                             2.0
# 102597              0.10                3.0                             1.0
#
#         availability 365                                        house_rules
# 0                  286.0  Clean up and treat the home the way you'd like...
# 1                  228.0  Pet friendly but please confirm with me if the...
# 4                  289.0  Please no smoking in the house, porch or on th...
# 5                  374.0                  No smoking, please, and no drugs.
# 7                  219.0  House Guidelines for our BnB We are delighted ...
# ...                  ...                                                ...
# 102588             410.0   Keep the apartment clean and damage free please.
# 102591             134.0                                             #NAME?
# 102593             152.0  * No smoking indoors.  * No pets  * No loud/la...
# 102595             395.0  House rules: Guests agree to the following ter...
# 102597             386.0                                                NaN
#
# [83878 rows x 25 columns]

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
'country code', 'instant_bookable', 'cancellation_policy', 'room type',
'Construction year', 'price', 'service fee', 'minimum nights',
'number of reviews', 'last review']
columns_to_drop = ['reviews per month',
'review rate number', 'calculated host listings count',
'availability 365', 'house_rules', 'License', 'id']

# %%
dfc = dfc[columns_to_keep]
dfc
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102588          Loft Space for Events, Meetings & Shoots  85557432222
# 102591                Columbus Ave Apt 1 block from Park  50908010324
# 102593               Welcoming, Clean, Cheap on St Marks  33188605074
# 102595                     Best Location near Columbia U  77864383453
# 102597                  Big Studio-One Stop from Midtown  11160591270
#
#        host_identity_verified    host name neighbourhood group  \
# 0                 unconfirmed     Madaline            Brooklyn
# 1                    verified        Jenna           Manhattan
# 4                    verified       Lyndon           Manhattan
# 5                    verified     Michelle           Manhattan
# 7                 unconfirmed         Emma            Brooklyn
# ...                       ...          ...                 ...
# 102588            unconfirmed        Kalin           Manhattan
# 102591               verified     Lawrence           Manhattan
# 102593               verified       Felipe           Manhattan
# 102595            unconfirmed        Mifan           Manhattan
# 102597            unconfirmed  Christopher              Queens
#
#               neighbourhood       lat      long        country country code  \
# 0                Kensington  40.64749 -73.97237  United States           US
# 1                   Midtown  40.75362 -73.98377  United States           US
# 4               East Harlem  40.79851 -73.94399  United States           US
# 5               Murray Hill  40.74767 -73.97500  United States           US
# 7        Bedford-Stuyvesant  40.68688 -73.95596  United States           US
# ...                     ...       ...       ...            ...          ...
# 102588    Flatiron District  40.74068 -73.98999  United States           US
# 102591      Upper West Side  40.77408 -73.98181  United States           US
# 102593         East Village  40.72826 -73.98422  United States           US
# 102595  Morningside Heights  40.80460 -73.96545  United States           US
# 102597     Long Island City  40.74989 -73.93777  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# 4                 False            moderate  Entire home/apt
# 5                  True            flexible  Entire home/apt
# 7                 False            moderate     Private room
# ...                 ...                 ...              ...
# 102588             True            flexible  Entire home/apt
# 102591            False              strict  Entire home/apt
# 102593             True              strict     Private room
# 102595             True            moderate     Private room
# 102597             True              strict  Entire home/apt
#
#         Construction year    price service fee  minimum nights  \
# 0                  2020.0    $966        $193             10.0
# 1                  2007.0    $142         $28             30.0
# 4                  2009.0    $204         $41             10.0
# 5                  2013.0    $577        $115              3.0
# 7                  2009.0  $1,060        $212             45.0
# ...                   ...      ...         ...             ...
# 102588             2016.0    $618        $124              1.0
# 102591             2005.0  $1,139        $228              5.0
# 102593             2017.0  $1,099        $220              1.0
# 102595             2016.0    $837        $167              1.0
# 102597             2015.0    $546        $109              2.0
#
#         number of reviews last review
# 0                     9.0  10/19/2021
# 1                    45.0   5/21/2022
# 4                     9.0  11/19/2018
# 5                    74.0   6/22/2019
# 7                    49.0   10/5/2017
# ...                   ...         ...
# 102588              177.0   6/29/2019
# 102591               17.0    1/4/2019
# 102593                8.0    9/6/2015
# 102595                1.0    7/6/2015
# 102597                5.0  10/11/2015
#
# [83878 rows x 19 columns]

# %%
dfc['neighbourhood group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'brookln', 'Queens', 'Bronx',
#        'Staten Island'], dtype=object)

# %%
# Extract meanings of cancellation policy, room type, service fee, and review differences
# Define a dictionary for cancellation policy meanings
cancellation_policy_meanings = {
    "strict": "No refund if canceled late",
    "moderate": "Partial refund if canceled",
    "flexible": "Full refund if canceled early"
}
# Define a dictionary for room type meanings
room_type_meanings = {
    "Private room": "A private room in a shared space",
    "Entire home/apt": "The entire property is rented",
    "Shared room": "A shared room in a shared space"
}
# Define the meaning of service fee
service_fee_meaning = "A fee charged for services provided"
# Calculate the difference between all reviews
dfc['Answer'] = dfc['number of reviews'].max() - dfc['number of reviews'].min()
# Combine all meanings and differences into a DataFrame
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\765932898.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['Answer'] = dfc['number of reviews'].max() - dfc['number of reviews'].min()

# %%
dfc.price = dfc.price.str.replace(',',repl='').str.replace('$','').astype(int)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\2143119411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.price = dfc.price.str.replace(',',repl='').str.replace('$','').astype(int)

# %%
dfc['service fee'] = dfc['service fee'].str.replace(',',repl='').str.replace('$','').astype(int)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\404591309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['service fee'] = dfc['service fee'].str.replace(',',repl='').str.replace('$','').astype(int)

# %%
dfc
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102588          Loft Space for Events, Meetings & Shoots  85557432222
# 102591                Columbus Ave Apt 1 block from Park  50908010324
# 102593               Welcoming, Clean, Cheap on St Marks  33188605074
# 102595                     Best Location near Columbia U  77864383453
# 102597                  Big Studio-One Stop from Midtown  11160591270
#
#        host_identity_verified    host name neighbourhood group  \
# 0                 unconfirmed     Madaline            Brooklyn
# 1                    verified        Jenna           Manhattan
# 4                    verified       Lyndon           Manhattan
# 5                    verified     Michelle           Manhattan
# 7                 unconfirmed         Emma            Brooklyn
# ...                       ...          ...                 ...
# 102588            unconfirmed        Kalin           Manhattan
# 102591               verified     Lawrence           Manhattan
# 102593               verified       Felipe           Manhattan
# 102595            unconfirmed        Mifan           Manhattan
# 102597            unconfirmed  Christopher              Queens
#
#               neighbourhood       lat      long        country country code  \
# 0                Kensington  40.64749 -73.97237  United States           US
# 1                   Midtown  40.75362 -73.98377  United States           US
# 4               East Harlem  40.79851 -73.94399  United States           US
# 5               Murray Hill  40.74767 -73.97500  United States           US
# 7        Bedford-Stuyvesant  40.68688 -73.95596  United States           US
# ...                     ...       ...       ...            ...          ...
# 102588    Flatiron District  40.74068 -73.98999  United States           US
# 102591      Upper West Side  40.77408 -73.98181  United States           US
# 102593         East Village  40.72826 -73.98422  United States           US
# 102595  Morningside Heights  40.80460 -73.96545  United States           US
# 102597     Long Island City  40.74989 -73.93777  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# 4                 False            moderate  Entire home/apt
# 5                  True            flexible  Entire home/apt
# 7                 False            moderate     Private room
# ...                 ...                 ...              ...
# 102588             True            flexible  Entire home/apt
# 102591            False              strict  Entire home/apt
# 102593             True              strict     Private room
# 102595             True            moderate     Private room
# 102597             True              strict  Entire home/apt
#
#         Construction year  price  service fee  minimum nights  \
# 0                  2020.0    966          193            10.0
# 1                  2007.0    142           28            30.0
# 4                  2009.0    204           41            10.0
# 5                  2013.0    577          115             3.0
# 7                  2009.0   1060          212            45.0
# ...                   ...    ...          ...             ...
# 102588             2016.0    618          124             1.0
# 102591             2005.0   1139          228             5.0
# 102593             2017.0   1099          220             1.0
# 102595             2016.0    837          167             1.0
# 102597             2015.0    546          109             2.0
#
#         number of reviews last review  Answer
# 0                     9.0  10/19/2021  1023.0
# 1                    45.0   5/21/2022  1023.0
# 4                     9.0  11/19/2018  1023.0
# 5                    74.0   6/22/2019  1023.0
# 7                    49.0   10/5/2017  1023.0
# ...                   ...         ...     ...
# 102588              177.0   6/29/2019  1023.0
# 102591               17.0    1/4/2019  1023.0
# 102593                8.0    9/6/2015  1023.0
# 102595                1.0    7/6/2015  1023.0
# 102597                5.0  10/11/2015  1023.0
#
# [83878 rows x 20 columns]

# %%
dfc.drop(index= dfc[dfc['minimum nights'] < 0 ].index, inplace=True)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\1329387656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.drop(index= dfc[dfc['minimum nights'] < 0 ].index, inplace=True)

# %%
dfc[dfc['minimum nights'] < 0 ]
# Out:
# Empty DataFrame
# Columns: [NAME, host id, host_identity_verified, host name, neighbourhood group, neighbourhood, lat, long, country, country code, instant_bookable, cancellation_policy, room type, Construction year, price, service fee, minimum nights, number of reviews, last review, Answer]
# Index: []

# %%
dfc
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102588          Loft Space for Events, Meetings & Shoots  85557432222
# 102591                Columbus Ave Apt 1 block from Park  50908010324
# 102593               Welcoming, Clean, Cheap on St Marks  33188605074
# 102595                     Best Location near Columbia U  77864383453
# 102597                  Big Studio-One Stop from Midtown  11160591270
#
#        host_identity_verified    host name neighbourhood group  \
# 0                 unconfirmed     Madaline            Brooklyn
# 1                    verified        Jenna           Manhattan
# 4                    verified       Lyndon           Manhattan
# 5                    verified     Michelle           Manhattan
# 7                 unconfirmed         Emma            Brooklyn
# ...                       ...          ...                 ...
# 102588            unconfirmed        Kalin           Manhattan
# 102591               verified     Lawrence           Manhattan
# 102593               verified       Felipe           Manhattan
# 102595            unconfirmed        Mifan           Manhattan
# 102597            unconfirmed  Christopher              Queens
#
#               neighbourhood       lat      long        country country code  \
# 0                Kensington  40.64749 -73.97237  United States           US
# 1                   Midtown  40.75362 -73.98377  United States           US
# 4               East Harlem  40.79851 -73.94399  United States           US
# 5               Murray Hill  40.74767 -73.97500  United States           US
# 7        Bedford-Stuyvesant  40.68688 -73.95596  United States           US
# ...                     ...       ...       ...            ...          ...
# 102588    Flatiron District  40.74068 -73.98999  United States           US
# 102591      Upper West Side  40.77408 -73.98181  United States           US
# 102593         East Village  40.72826 -73.98422  United States           US
# 102595  Morningside Heights  40.80460 -73.96545  United States           US
# 102597     Long Island City  40.74989 -73.93777  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# 4                 False            moderate  Entire home/apt
# 5                  True            flexible  Entire home/apt
# 7                 False            moderate     Private room
# ...                 ...                 ...              ...
# 102588             True            flexible  Entire home/apt
# 102591            False              strict  Entire home/apt
# 102593             True              strict     Private room
# 102595             True            moderate     Private room
# 102597             True              strict  Entire home/apt
#
#         Construction year  price  service fee  minimum nights  \
# 0                  2020.0    966          193            10.0
# 1                  2007.0    142           28            30.0
# 4                  2009.0    204           41            10.0
# 5                  2013.0    577          115             3.0
# 7                  2009.0   1060          212            45.0
# ...                   ...    ...          ...             ...
# 102588             2016.0    618          124             1.0
# 102591             2005.0   1139          228             5.0
# 102593             2017.0   1099          220             1.0
# 102595             2016.0    837          167             1.0
# 102597             2015.0    546          109             2.0
#
#         number of reviews last review  Answer
# 0                     9.0  10/19/2021  1023.0
# 1                    45.0   5/21/2022  1023.0
# 4                     9.0  11/19/2018  1023.0
# 5                    74.0   6/22/2019  1023.0
# 7                    49.0   10/5/2017  1023.0
# ...                   ...         ...     ...
# 102588              177.0   6/29/2019  1023.0
# 102591               17.0    1/4/2019  1023.0
# 102593                8.0    9/6/2015  1023.0
# 102595                1.0    7/6/2015  1023.0
# 102597                5.0  10/11/2015  1023.0
#
# [83868 rows x 20 columns]

# %%
# ! convert to int
dfc[['Construction year','minimum nights','number of reviews']] = dfc[['Construction year','minimum nights','number of reviews']].astype(int)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\1856185354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc[['Construction year','minimum nights','number of reviews']] = dfc[['Construction year','minimum nights','number of reviews']].astype(int)

# %%
dfc
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102588          Loft Space for Events, Meetings & Shoots  85557432222
# 102591                Columbus Ave Apt 1 block from Park  50908010324
# 102593               Welcoming, Clean, Cheap on St Marks  33188605074
# 102595                     Best Location near Columbia U  77864383453
# 102597                  Big Studio-One Stop from Midtown  11160591270
#
#        host_identity_verified    host name neighbourhood group  \
# 0                 unconfirmed     Madaline            Brooklyn
# 1                    verified        Jenna           Manhattan
# 4                    verified       Lyndon           Manhattan
# 5                    verified     Michelle           Manhattan
# 7                 unconfirmed         Emma            Brooklyn
# ...                       ...          ...                 ...
# 102588            unconfirmed        Kalin           Manhattan
# 102591               verified     Lawrence           Manhattan
# 102593               verified       Felipe           Manhattan
# 102595            unconfirmed        Mifan           Manhattan
# 102597            unconfirmed  Christopher              Queens
#
#               neighbourhood       lat      long        country country code  \
# 0                Kensington  40.64749 -73.97237  United States           US
# 1                   Midtown  40.75362 -73.98377  United States           US
# 4               East Harlem  40.79851 -73.94399  United States           US
# 5               Murray Hill  40.74767 -73.97500  United States           US
# 7        Bedford-Stuyvesant  40.68688 -73.95596  United States           US
# ...                     ...       ...       ...            ...          ...
# 102588    Flatiron District  40.74068 -73.98999  United States           US
# 102591      Upper West Side  40.77408 -73.98181  United States           US
# 102593         East Village  40.72826 -73.98422  United States           US
# 102595  Morningside Heights  40.80460 -73.96545  United States           US
# 102597     Long Island City  40.74989 -73.93777  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# 4                 False            moderate  Entire home/apt
# 5                  True            flexible  Entire home/apt
# 7                 False            moderate     Private room
# ...                 ...                 ...              ...
# 102588             True            flexible  Entire home/apt
# 102591            False              strict  Entire home/apt
# 102593             True              strict     Private room
# 102595             True            moderate     Private room
# 102597             True              strict  Entire home/apt
#
#         Construction year  price  service fee  minimum nights  \
# 0                    2020    966          193              10
# 1                    2007    142           28              30
# 4                    2009    204           41              10
# 5                    2013    577          115               3
# 7                    2009   1060          212              45
# ...                   ...    ...          ...             ...
# 102588               2016    618          124               1
# 102591               2005   1139          228               5
# 102593               2017   1099          220               1
# 102595               2016    837          167               1
# 102597               2015    546          109               2
#
#         number of reviews last review  Answer
# 0                       9  2021-10-19  1023.0
# 1                      45  2022-05-21  1023.0
# 4                       9  2018-11-19  1023.0
# 5                      74  2019-06-22  1023.0
# 7                      49  2017-10-05  1023.0
# ...                   ...         ...     ...
# 102588                177  2019-06-29  1023.0
# 102591                 17  2019-01-04  1023.0
# 102593                  8  2015-09-06  1023.0
# 102595                  1  2015-07-06  1023.0
# 102597                  5  2015-10-11  1023.0
#
# [83868 rows x 20 columns]

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83868 entries, 0 to 102597
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NAME                    83868 non-null  object
#  1   host id                 83868 non-null  int64
#  2   host_identity_verified  83868 non-null  object
#  3   host name               83868 non-null  object
#  4   neighbourhood group     83868 non-null  object
#  5   neighbourhood           83868 non-null  object
#  6   lat                     83868 non-null  float64
#  7   long                    83868 non-null  float64
#  8   country                 83868 non-null  object
#  9   country code            83868 non-null  object
#  10  instant_bookable        83868 non-null  object
#  11  cancellation_policy     83868 non-null  object
#  12  room type               83868 non-null  object
#  13  Construction year       83868 non-null  int64
#  14  price                   83868 non-null  int64
#  15  service fee             83868 non-null  int64
#  16  minimum nights          83868 non-null  int64
#  17  number of reviews       83868 non-null  int64
#  18  last review             83868 non-null  datetime64[ns]
#  19  Answer                  83868 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(6), object(10)
# memory usage: 13.4+ MB

# %%
dfc['last review']= pd.to_datetime(dfc['last review'])
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\2539343198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['last review']= pd.to_datetime(dfc['last review'])

# %%
dfc.drop(columns='Answer',inplace=True)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\1556519029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.drop(columns='Answer',inplace=True)

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83868 entries, 0 to 102597
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NAME                    83868 non-null  object
#  1   host id                 83868 non-null  int64
#  2   host_identity_verified  83868 non-null  object
#  3   host name               83868 non-null  object
#  4   neighbourhood group     83868 non-null  object
#  5   neighbourhood           83868 non-null  object
#  6   lat                     83868 non-null  float64
#  7   long                    83868 non-null  float64
#  8   country                 83868 non-null  object
#  9   country code            83868 non-null  object
#  10  instant_bookable        83868 non-null  object
#  11  cancellation_policy     83868 non-null  object
#  12  room type               83868 non-null  object
#  13  Construction year       83868 non-null  int64
#  14  price                   83868 non-null  int64
#  15  service fee             83868 non-null  int64
#  16  minimum nights          83868 non-null  int64
#  17  number of reviews       83868 non-null  int64
#  18  last review             83868 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(6), object(10)
# memory usage: 12.8+ MB

# %%
dfc.drop(columns=['country code','country'],inplace=True)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\2965384552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.drop(columns=['country code','country'],inplace=True)

# %%
dfc
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102588          Loft Space for Events, Meetings & Shoots  85557432222
# 102591                Columbus Ave Apt 1 block from Park  50908010324
# 102593               Welcoming, Clean, Cheap on St Marks  33188605074
# 102595                     Best Location near Columbia U  77864383453
# 102597                  Big Studio-One Stop from Midtown  11160591270
#
#        host_identity_verified    host name neighbourhood group  \
# 0                 Unconfirmed     Madaline            Brooklyn
# 1                    Verified        Jenna           Manhattan
# 4                    Verified       Lyndon           Manhattan
# 5                    Verified     Michelle           Manhattan
# 7                 Unconfirmed         Emma            Brooklyn
# ...                       ...          ...                 ...
# 102588            Unconfirmed        Kalin           Manhattan
# 102591               Verified     Lawrence           Manhattan
# 102593               Verified       Felipe           Manhattan
# 102595            Unconfirmed        Mifan           Manhattan
# 102597            Unconfirmed  Christopher              Queens
#
#               neighbourhood       lat      long instant_bookable  \
# 0                Kensington  40.64749 -73.97237            False
# 1                   Midtown  40.75362 -73.98377            False
# 4               East Harlem  40.79851 -73.94399            False
# 5               Murray Hill  40.74767 -73.97500             True
# 7        Bedford-Stuyvesant  40.68688 -73.95596            False
# ...                     ...       ...       ...              ...
# 102588    Flatiron District  40.74068 -73.98999             True
# 102591      Upper West Side  40.77408 -73.98181            False
# 102593         East Village  40.72826 -73.98422             True
# 102595  Morningside Heights  40.80460 -73.96545             True
# 102597     Long Island City  40.74989 -73.93777             True
#
#        cancellation_policy        room type  Construction year  price  \
# 0                   Strict     Private room               2020    966
# 1                 Moderate  Entire home/apt               2007    142
# 4                 Moderate  Entire home/apt               2009    204
# 5                 Flexible  Entire home/apt               2013    577
# 7                 Moderate     Private room               2009   1060
# ...                    ...              ...                ...    ...
# 102588            Flexible  Entire home/apt               2016    618
# 102591              Strict  Entire home/apt               2005   1139
# 102593              Strict     Private room               2017   1099
# 102595            Moderate     Private room               2016    837
# 102597              Strict  Entire home/apt               2015    546
#
#         service fee  minimum nights  number of reviews last review
# 0               193              10                  9  2021-10-19
# 1                28              30                 45  2022-05-21
# 4                41              10                  9  2018-11-19
# 5               115               3                 74  2019-06-22
# 7               212              45                 49  2017-10-05
# ...             ...             ...                ...         ...
# 102588          124               1                177  2019-06-29
# 102591          228               5                 17  2019-01-04
# 102593          220               1                  8  2015-09-06
# 102595          167               1                  1  2015-07-06
# 102597          109               2                  5  2015-10-11
#
# [83868 rows x 17 columns]

# %%
dfc['host_identity_verified']= dfc['host_identity_verified'].str.title()
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\473670654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['host_identity_verified']= dfc['host_identity_verified'].str.title()

# %%
dfc['neighbourhood group'].replace('brookln','Brooklyn',inplace=True)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\3690244757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['neighbourhood group'].replace('brookln','Brooklyn',inplace=True)

# %%
dfc['cancellation_policy']= dfc['cancellation_policy'].str.title()
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\1482727358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['cancellation_policy']= dfc['cancellation_policy'].str.title()

# %%
dfc.instant_bookable = dfc.instant_bookable.astype(bool)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\3584494969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.instant_bookable = dfc.instant_bookable.astype(bool)

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83868 entries, 0 to 102597
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NAME                    83868 non-null  object
#  1   host id                 83868 non-null  int64
#  2   host_identity_verified  83868 non-null  object
#  3   host name               83868 non-null  object
#  4   neighbourhood group     83868 non-null  object
#  5   neighbourhood           83868 non-null  object
#  6   lat                     83868 non-null  float64
#  7   long                    83868 non-null  float64
#  8   instant_bookable        83868 non-null  bool
#  9   cancellation_policy     83868 non-null  object
#  10  room type               83868 non-null  object
#  11  Construction year       83868 non-null  int64
#  12  price                   83868 non-null  int64
#  13  service fee             83868 non-null  int64
#  14  minimum nights          83868 non-null  int64
#  15  number of reviews       83868 non-null  int64
#  16  last review             83868 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(6), object(7)
# memory usage: 11.0+ MB

# %%
dfc.NAME.rename('name',inplace=True)
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 4         Entire Apt: Spacious Studio/Loft by central park
# 5                Large Cozy 1 BR Apartment In Midtown East
# 7                                          BlissArtsSpace!
#                                 ...
# 102588            Loft Space for Events, Meetings & Shoots
# 102591                  Columbus Ave Apt 1 block from Park
# 102593                 Welcoming, Clean, Cheap on St Marks
# 102595                       Best Location near Columbia U
# 102597                    Big Studio-One Stop from Midtown
# Name: name, Length: 83868, dtype: object

# %%
dfc.host_identity_verified.rename('host identity verified',inplace=True)
# Out:
# 0         Unconfirmed
# 1            Verified
# 4            Verified
# 5            Verified
# 7         Unconfirmed
#              ...
# 102588    Unconfirmed
# 102591       Verified
# 102593       Verified
# 102595    Unconfirmed
# 102597    Unconfirmed
# Name: host identity verified, Length: 83868, dtype: object

# %%
dfc.rename(columns={'host_identity_verified': 'host identity verified'},inplace=True)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\1632284260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.rename(columns={'host_identity_verified': 'host identity verified'},inplace=True)

# %%
dfc.rename(columns={'NAME': 'name'},inplace=True)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\1913760548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.rename(columns={'NAME': 'name'},inplace=True)

# %%
dfc.rename(columns={'cancellation_policy': 'cancellation policy'},inplace=True)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\1599549953.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.rename(columns={'cancellation_policy': 'cancellation policy'},inplace=True)

# %%
dfc.rename(columns={'instant_bookable': 'instant bookable'},inplace=True)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\3479735812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.rename(columns={'instant_bookable': 'instant bookable'},inplace=True)

# %%
dfc.rename(columns={'Construction year': 'construction year'},inplace=True)
# Out:
# C:\Users\YUSEF\AppData\Local\Temp\ipykernel_24544\1623772006.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc.rename(columns={'Construction year': 'construction year'},inplace=True)

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83868 entries, 0 to 102597
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    83868 non-null  object
#  1   host id                 83868 non-null  int64
#  2   host identity verified  83868 non-null  object
#  3   host name               83868 non-null  object
#  4   neighbourhood group     83868 non-null  object
#  5   neighbourhood           83868 non-null  object
#  6   lat                     83868 non-null  float64
#  7   long                    83868 non-null  float64
#  8   instant bookable        83868 non-null  bool
#  9   cancellation policy     83868 non-null  object
#  10  room type               83868 non-null  object
#  11  construction year       83868 non-null  int64
#  12  price                   83868 non-null  int64
#  13  service fee             83868 non-null  int64
#  14  minimum nights          83868 non-null  int64
#  15  number of reviews       83868 non-null  int64
#  16  last review             83868 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(6), object(7)
# memory usage: 13.0+ MB

# %%
dfc
# Out:
#                                                     name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102588          Loft Space for Events, Meetings & Shoots  85557432222
# 102591                Columbus Ave Apt 1 block from Park  50908010324
# 102593               Welcoming, Clean, Cheap on St Marks  33188605074
# 102595                     Best Location near Columbia U  77864383453
# 102597                  Big Studio-One Stop from Midtown  11160591270
#
#        host identity verified    host name neighbourhood group  \
# 0                 Unconfirmed     Madaline            Brooklyn
# 1                    Verified        Jenna           Manhattan
# 4                    Verified       Lyndon           Manhattan
# 5                    Verified     Michelle           Manhattan
# 7                 Unconfirmed         Emma            Brooklyn
# ...                       ...          ...                 ...
# 102588            Unconfirmed        Kalin           Manhattan
# 102591               Verified     Lawrence           Manhattan
# 102593               Verified       Felipe           Manhattan
# 102595            Unconfirmed        Mifan           Manhattan
# 102597            Unconfirmed  Christopher              Queens
#
#               neighbourhood       lat      long  instant bookable  \
# 0                Kensington  40.64749 -73.97237             False
# 1                   Midtown  40.75362 -73.98377             False
# 4               East Harlem  40.79851 -73.94399             False
# 5               Murray Hill  40.74767 -73.97500              True
# 7        Bedford-Stuyvesant  40.68688 -73.95596             False
# ...                     ...       ...       ...               ...
# 102588    Flatiron District  40.74068 -73.98999              True
# 102591      Upper West Side  40.77408 -73.98181             False
# 102593         East Village  40.72826 -73.98422              True
# 102595  Morningside Heights  40.80460 -73.96545              True
# 102597     Long Island City  40.74989 -73.93777              True
#
#        cancellation policy        room type  construction year  price  \
# 0                   Strict     Private room               2020    966
# 1                 Moderate  Entire home/apt               2007    142
# 4                 Moderate  Entire home/apt               2009    204
# 5                 Flexible  Entire home/apt               2013    577
# 7                 Moderate     Private room               2009   1060
# ...                    ...              ...                ...    ...
# 102588            Flexible  Entire home/apt               2016    618
# 102591              Strict  Entire home/apt               2005   1139
# 102593              Strict     Private room               2017   1099
# 102595            Moderate     Private room               2016    837
# 102597              Strict  Entire home/apt               2015    546
#
#         service fee  minimum nights  number of reviews last review
# 0               193              10                  9  2021-10-19
# 1                28              30                 45  2022-05-21
# 4                41              10                  9  2018-11-19
# 5               115               3                 74  2019-06-22
# 7               212              45                 49  2017-10-05
# ...             ...             ...                ...         ...
# 102588          124               1                177  2019-06-29
# 102591          228               5                 17  2019-01-04
# 102593          220               1                  8  2015-09-06
# 102595          167               1                  1  2015-07-06
# 102597          109               2                  5  2015-10-11
#
# [83868 rows x 17 columns]

# %%
dfc.columns = dfc.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83868 entries, 0 to 102597
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    83868 non-null  object
#  1   host_id                 83868 non-null  int64
#  2   host_identity_verified  83868 non-null  object
#  3   host_name               83868 non-null  object
#  4   neighbourhood_group     83868 non-null  object
#  5   neighbourhood           83868 non-null  object
#  6   lat                     83868 non-null  float64
#  7   long                    83868 non-null  float64
#  8   instant_bookable        83868 non-null  bool
#  9   cancellation_policy     83868 non-null  object
#  10  room_type               83868 non-null  object
#  11  construction_year       83868 non-null  int64
#  12  price                   83868 non-null  int64
#  13  service_fee             83868 non-null  int64
#  14  minimum_nights          83868 non-null  int64
#  15  number_of_reviews       83868 non-null  int64
#  16  last_review             83868 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(6), object(7)
# memory usage: 13.0+ MB

# %% [markdown]
# ## The Cleaning is Done 👌👌👌👌

# %%
dfc.to_csv('Airbnb.csv')
